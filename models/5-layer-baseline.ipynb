# %%
#importing libraries
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import imageio

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout,Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model
from sklearn.utils import class_weight
import tensorflow as tf

# %%
train_dir='/kaggle/input/fer2013/facial_data/train'
val_dir='/kaggle/input/fer2013/facial_data/validation'
test_dir='/kaggle/input/fer2013/facial_data/test'

# %%
img_size = 48
batch_size = 128
datagen=ImageDataGenerator(
                            rescale=1./255,
                            featurewise_center=False,
                            featurewise_std_normalization=False,
                            rotation_range=10,
                            width_shift_range=0.1,
                            height_shift_range=0.1,
                            zoom_range=0.1,
                            horizontal_flip=True)
train_gen=datagen.flow_from_directory(              train_dir,
                                                    target_size=(img_size,img_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)
datagen_=ImageDataGenerator(rescale=1./255)
val_gen = datagen_.flow_from_directory(val_dir,
                                                    target_size=(img_size,img_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)
test_gen = datagen_.flow_from_directory(test_dir,
                                                    target_size=(img_size,img_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)
# Out:
# Found 28708 images belonging to 7 classes.
# Found 3589 images belonging to 7 classes.
# Found 3589 images belonging to 7 classes.

# %%
model=Sequential()
# 1 - Convolution
model.add(Conv2D(32,(5,5), padding='same', input_shape=(48, 48,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3),strides=2))

# 2nd Convolution layer
model.add(Conv2D(32,(4,4), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3),strides=2))

# 3rd Convolution layer
model.add(Conv2D(64,(5,5), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3),strides=2))

model.add(Flatten())
model.add(Dense(1024))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(7, activation='softmax'))

opt=keras.optimizers.SGD(learning_rate=0.01,weight_decay=0.0001,momentum=0.9,nesterov=True)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        832
#
#  batch_normalization (Batch  (None, 48, 48, 32)        128
#  Normalization)
#
#  activation (Activation)     (None, 48, 48, 32)        0
#
#  max_pooling2d (MaxPooling2  (None, 23, 23, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 23, 23, 32)        16416
#
#  batch_normalization_1 (Bat  (None, 23, 23, 32)        128
#  chNormalization)
#
#  activation_1 (Activation)   (None, 23, 23, 32)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 11, 11, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 11, 11, 64)        51264
#
#  batch_normalization_2 (Bat  (None, 11, 11, 64)        256
#  chNormalization)
#
#  activation_2 (Activation)   (None, 11, 11, 64)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 1024)              1639424
#
#  batch_normalization_3 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  activation_3 (Activation)   (None, 1024)              0
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 1719719 (6.56 MB)
# Trainable params: 1717415 (6.55 MB)
# Non-trainable params: 2304 (9.00 KB)
# _________________________________________________________________

# %%
labels=train_gen.classes
class_weights = class_weight.compute_class_weight(class_weight='balanced', classes=np.unique(labels), y=labels)
class_weights = dict(zip(np.unique(labels), class_weights))

# %%
epoch=150
rlrop = keras.callbacks.ReduceLROnPlateau(monitor='val_acc',mode='max',factor=0.5, patience=10, min_lr=0.00001, verbose=1)
checkpoint = ModelCheckpoint("model_weights.h5", monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [rlrop,checkpoint]

# %%
history = model.fit(
    x=train_gen,
    epochs=epoch,
    callbacks=callbacks_list,
    validation_data=val_gen,
)
# Out:
# Epoch 1/150
# 225/225 [==============================] - 109s 447ms/step - loss: 1.7642 - accuracy: 0.3316 - val_loss: 2.1914 - val_accuracy: 0.1605 - lr: 0.0100
# Epoch 2/150
# 225/225 [==============================] - 42s 187ms/step - loss: 1.5028 - accuracy: 0.4263 - val_loss: 2.0334 - val_accuracy: 0.3118 - lr: 0.0100
# Epoch 3/150
# 225/225 [==============================] - 41s 183ms/step - loss: 1.3945 - accuracy: 0.4707 - val_loss: 1.5215 - val_accuracy: 0.4308 - lr: 0.0100
# Epoch 4/150
# 225/225 [==============================] - 41s 184ms/step - loss: 1.3363 - accuracy: 0.4940 - val_loss: 1.3745 - val_accuracy: 0.4795 - lr: 0.0100
# Epoch 5/150
# 225/225 [==============================] - 44s 194ms/step - loss: 1.2928 - accuracy: 0.5142 - val_loss: 1.8835 - val_accuracy: 0.3525 - lr: 0.0100
# Epoch 6/150
# 225/225 [==============================] - 45s 200ms/step - loss: 1.2571 - accuracy: 0.5209 - val_loss: 1.2201 - val_accuracy: 0.5411 - lr: 0.0100
# Epoch 7/150
# 225/225 [==============================] - 43s 191ms/step - loss: 1.2310 - accuracy: 0.5336 - val_loss: 1.5068 - val_accuracy: 0.4519 - lr: 0.0100
# Epoch 8/150
# 225/225 [==============================] - 42s 186ms/step - loss: 1.2056 - accuracy: 0.5449 - val_loss: 1.5895 - val_accuracy: 0.4698 - lr: 0.0100
# Epoch 9/150
# 225/225 [==============================] - 41s 182ms/step - loss: 1.1941 - accuracy: 0.5495 - val_loss: 1.4984 - val_accuracy: 0.4143 - lr: 0.0100
# Epoch 10/150
# 225/225 [==============================] - 41s 183ms/step - loss: 1.1720 - accuracy: 0.5555 - val_loss: 1.2391 - val_accuracy: 0.5358 - lr: 0.0100
# Epoch 11/150
# 225/225 [==============================] - 45s 202ms/step - loss: 1.1574 - accuracy: 0.5628 - val_loss: 1.2808 - val_accuracy: 0.5077 - lr: 0.0100
# Epoch 12/150
# 225/225 [==============================] - 41s 184ms/step - loss: 1.1483 - accuracy: 0.5657 - val_loss: 1.1580 - val_accuracy: 0.5628 - lr: 0.0100
# Epoch 13/150
# 225/225 [==============================] - 42s 188ms/step - loss: 1.1305 - accuracy: 0.5761 - val_loss: 1.1609 - val_accuracy: 0.5695 - lr: 0.0100
# Epoch 14/150
# 225/225 [==============================] - 44s 194ms/step - loss: 1.1185 - accuracy: 0.5771 - val_loss: 1.2209 - val_accuracy: 0.5319 - lr: 0.0100
# Epoch 15/150
# 225/225 [==============================] - 42s 188ms/step - loss: 1.1055 - accuracy: 0.5819 - val_loss: 1.1788 - val_accuracy: 0.5651 - lr: 0.0100
# Epoch 16/150
# 225/225 [==============================] - 42s 185ms/step - loss: 1.0980 - accuracy: 0.5851 - val_loss: 1.1599 - val_accuracy: 0.5701 - lr: 0.0100
# Epoch 17/150
# 225/225 [==============================] - 41s 182ms/step - loss: 1.0824 - accuracy: 0.5908 - val_loss: 1.3558 - val_accuracy: 0.5004 - lr: 0.0100
# Epoch 18/150
# 225/225 [==============================] - 41s 182ms/step - loss: 1.0761 - accuracy: 0.5948 - val_loss: 1.1984 - val_accuracy: 0.5600 - lr: 0.0100
# Epoch 19/150
# 225/225 [==============================] - 41s 182ms/step - loss: 1.0649 - accuracy: 0.6006 - val_loss: 1.1509 - val_accuracy: 0.5784 - lr: 0.0100
# Epoch 20/150
# 225/225 [==============================] - 43s 192ms/step - loss: 1.0600 - accuracy: 0.5988 - val_loss: 1.1744 - val_accuracy: 0.5857 - lr: 0.0100
# Epoch 21/150
# 225/225 [==============================] - 42s 187ms/step - loss: 1.0483 - accuracy: 0.6021 - val_loss: 1.1721 - val_accuracy: 0.5776 - lr: 0.0100
# Epoch 22/150
# 225/225 [==============================] - 44s 194ms/step - loss: 1.0376 - accuracy: 0.6052 - val_loss: 1.1591 - val_accuracy: 0.5843 - lr: 0.0100
# Epoch 23/150
# 225/225 [==============================] - 44s 196ms/step - loss: 1.0345 - accuracy: 0.6105 - val_loss: 1.1476 - val_accuracy: 0.5837 - lr: 0.0100
# Epoch 24/150
# 225/225 [==============================] - 42s 188ms/step - loss: 1.0220 - accuracy: 0.6144 - val_loss: 1.5308 - val_accuracy: 0.4528 - lr: 0.0100
# Epoch 25/150
# 225/225 [==============================] - 42s 186ms/step - loss: 1.0156 - accuracy: 0.6177 - val_loss: 1.1547 - val_accuracy: 0.5756 - lr: 0.0100
# Epoch 26/150
# 225/225 [==============================] - 43s 192ms/step - loss: 1.0196 - accuracy: 0.6188 - val_loss: 1.1132 - val_accuracy: 0.6021 - lr: 0.0100
# Epoch 27/150
# 225/225 [==============================] - 43s 190ms/step - loss: 1.0008 - accuracy: 0.6224 - val_loss: 1.1636 - val_accuracy: 0.5734 - lr: 0.0100
# Epoch 28/150
# 225/225 [==============================] - 43s 190ms/step - loss: 0.9935 - accuracy: 0.6260 - val_loss: 1.1507 - val_accuracy: 0.5907 - lr: 0.0100
# Epoch 29/150
# 225/225 [==============================] - 43s 190ms/step - loss: 0.9864 - accuracy: 0.6271 - val_loss: 1.1324 - val_accuracy: 0.5946 - lr: 0.0100
# Epoch 30/150
# 225/225 [==============================] - 43s 191ms/step - loss: 0.9865 - accuracy: 0.6317 - val_loss: 1.1063 - val_accuracy: 0.5974 - lr: 0.0100
# Epoch 31/150
# 225/225 [==============================] - 42s 187ms/step - loss: 0.9704 - accuracy: 0.6333 - val_loss: 1.1226 - val_accuracy: 0.6016 - lr: 0.0100
# Epoch 32/150
# 225/225 [==============================] - 41s 184ms/step - loss: 0.9741 - accuracy: 0.6367 - val_loss: 1.1256 - val_accuracy: 0.5910 - lr: 0.0100
# Epoch 33/150
# 225/225 [==============================] - 43s 192ms/step - loss: 0.9613 - accuracy: 0.6403 - val_loss: 1.2029 - val_accuracy: 0.5801 - lr: 0.0100
# Epoch 34/150
# 225/225 [==============================] - 42s 188ms/step - loss: 0.9586 - accuracy: 0.6388 - val_loss: 1.0612 - val_accuracy: 0.6133 - lr: 0.0100
# Epoch 35/150
# 225/225 [==============================] - 41s 181ms/step - loss: 0.9608 - accuracy: 0.6400 - val_loss: 1.0730 - val_accuracy: 0.6127 - lr: 0.0100
# Epoch 36/150
# 225/225 [==============================] - 41s 182ms/step - loss: 0.9541 - accuracy: 0.6418 - val_loss: 1.0885 - val_accuracy: 0.5977 - lr: 0.0100
# Epoch 37/150
# 225/225 [==============================] - 43s 189ms/step - loss: 0.9414 - accuracy: 0.6461 - val_loss: 1.0932 - val_accuracy: 0.5979 - lr: 0.0100
# Epoch 38/150
# 225/225 [==============================] - 41s 182ms/step - loss: 0.9332 - accuracy: 0.6463 - val_loss: 1.2026 - val_accuracy: 0.5993 - lr: 0.0100
# Epoch 39/150
# 225/225 [==============================] - 41s 182ms/step - loss: 0.9299 - accuracy: 0.6495 - val_loss: 1.2138 - val_accuracy: 0.5715 - lr: 0.0100
# Epoch 40/150
# 225/225 [==============================] - 43s 190ms/step - loss: 0.9292 - accuracy: 0.6515 - val_loss: 1.1714 - val_accuracy: 0.5949 - lr: 0.0100
# Epoch 41/150
# 225/225 [==============================] - 41s 182ms/step - loss: 0.9247 - accuracy: 0.6519 - val_loss: 1.0661 - val_accuracy: 0.6138 - lr: 0.0100
# Epoch 42/150
# 225/225 [==============================] - 41s 184ms/step - loss: 0.9122 - accuracy: 0.6572 - val_loss: 1.0502 - val_accuracy: 0.6208 - lr: 0.0100
# Epoch 43/150
# 225/225 [==============================] - 41s 183ms/step - loss: 0.9140 - accuracy: 0.6577 - val_loss: 1.0862 - val_accuracy: 0.6077 - lr: 0.0100
# Epoch 44/150
# 225/225 [==============================] - 41s 181ms/step - loss: 0.9055 - accuracy: 0.6597 - val_loss: 1.1295 - val_accuracy: 0.6049 - lr: 0.0100
# Epoch 45/150
# 225/225 [==============================] - 41s 184ms/step - loss: 0.9047 - accuracy: 0.6595 - val_loss: 1.0542 - val_accuracy: 0.6163 - lr: 0.0100
# Epoch 46/150
# 225/225 [==============================] - 40s 177ms/step - loss: 0.8964 - accuracy: 0.6640 - val_loss: 1.1287 - val_accuracy: 0.5977 - lr: 0.0100
# Epoch 47/150
# 225/225 [==============================] - 41s 180ms/step - loss: 0.8980 - accuracy: 0.6639 - val_loss: 1.1189 - val_accuracy: 0.6024 - lr: 0.0100
# Epoch 48/150
# 225/225 [==============================] - 42s 187ms/step - loss: 0.8888 - accuracy: 0.6697 - val_loss: 1.2304 - val_accuracy: 0.5612 - lr: 0.0100
# Epoch 49/150
# 225/225 [==============================] - 41s 181ms/step - loss: 0.8793 - accuracy: 0.6678 - val_loss: 1.1023 - val_accuracy: 0.6202 - lr: 0.0100
# Epoch 50/150
# 225/225 [==============================] - 41s 182ms/step - loss: 0.8835 - accuracy: 0.6645 - val_loss: 1.2292 - val_accuracy: 0.5913 - lr: 0.0100
# Epoch 51/150
# 225/225 [==============================] - 42s 185ms/step - loss: 0.8775 - accuracy: 0.6697 - val_loss: 1.2491 - val_accuracy: 0.5500 - lr: 0.0100
# Epoch 52/150
# 225/225 [==============================] - 42s 187ms/step - loss: 0.8723 - accuracy: 0.6736 - val_loss: 1.0481 - val_accuracy: 0.6367 - lr: 0.0100
# Epoch 53/150
# 225/225 [==============================] - 42s 185ms/step - loss: 0.8680 - accuracy: 0.6762 - val_loss: 1.0206 - val_accuracy: 0.6386 - lr: 0.0100
# Epoch 54/150
# 225/225 [==============================] - 42s 185ms/step - loss: 0.8652 - accuracy: 0.6783 - val_loss: 1.1811 - val_accuracy: 0.5910 - lr: 0.0100
# Epoch 55/150
# 225/225 [==============================] - 42s 185ms/step - loss: 0.8618 - accuracy: 0.6772 - val_loss: 1.1202 - val_accuracy: 0.6113 - lr: 0.0100
# Epoch 56/150
# 225/225 [==============================] - 41s 182ms/step - loss: 0.8513 - accuracy: 0.6812 - val_loss: 1.0773 - val_accuracy: 0.6194 - lr: 0.0100
# Epoch 57/150
# 225/225 [==============================] - 42s 188ms/step - loss: 0.8486 - accuracy: 0.6832 - val_loss: 1.1050 - val_accuracy: 0.6141 - lr: 0.0100
# Epoch 58/150
# 225/225 [==============================] - 42s 188ms/step - loss: 0.8463 - accuracy: 0.6834 - val_loss: 1.0555 - val_accuracy: 0.6308 - lr: 0.0100
# Epoch 59/150
# 225/225 [==============================] - 41s 183ms/step - loss: 0.8463 - accuracy: 0.6849 - val_loss: 1.0475 - val_accuracy: 0.6322 - lr: 0.0100
# Epoch 60/150
# 225/225 [==============================] - 42s 186ms/step - loss: 0.8366 - accuracy: 0.6883 - val_loss: 1.0547 - val_accuracy: 0.6367 - lr: 0.0100
# Epoch 61/150
# 225/225 [==============================] - 43s 191ms/step - loss: 0.8315 - accuracy: 0.6880 - val_loss: 1.2184 - val_accuracy: 0.5926 - lr: 0.0100
# Epoch 62/150
# 225/225 [==============================] - 43s 190ms/step - loss: 0.8362 - accuracy: 0.6880 - val_loss: 1.1069 - val_accuracy: 0.6032 - lr: 0.0100
# Epoch 63/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.8240 - accuracy: 0.6927 - val_loss: 1.1656 - val_accuracy: 0.6163 - lr: 0.0100
# Epoch 64/150
# 225/225 [==============================] - 43s 193ms/step - loss: 0.8227 - accuracy: 0.6940 - val_loss: 1.0593 - val_accuracy: 0.6261 - lr: 0.0100
# Epoch 65/150
# 225/225 [==============================] - 42s 186ms/step - loss: 0.8172 - accuracy: 0.6979 - val_loss: 1.0876 - val_accuracy: 0.6230 - lr: 0.0100
# Epoch 66/150
# 225/225 [==============================] - 42s 188ms/step - loss: 0.8192 - accuracy: 0.6959 - val_loss: 1.0815 - val_accuracy: 0.6225 - lr: 0.0100
# Epoch 67/150
# 225/225 [==============================] - 45s 198ms/step - loss: 0.8096 - accuracy: 0.6979 - val_loss: 1.1835 - val_accuracy: 0.5991 - lr: 0.0100
# Epoch 68/150
# 225/225 [==============================] - 43s 190ms/step - loss: 0.8048 - accuracy: 0.7016 - val_loss: 1.1201 - val_accuracy: 0.6174 - lr: 0.0100
# Epoch 69/150
# 225/225 [==============================] - 42s 188ms/step - loss: 0.8030 - accuracy: 0.7013 - val_loss: 1.0956 - val_accuracy: 0.6336 - lr: 0.0100
# Epoch 70/150
# 225/225 [==============================] - 43s 189ms/step - loss: 0.7882 - accuracy: 0.7087 - val_loss: 1.2403 - val_accuracy: 0.5901 - lr: 0.0100
# Epoch 71/150
# 225/225 [==============================] - 43s 189ms/step - loss: 0.7923 - accuracy: 0.7067 - val_loss: 1.1395 - val_accuracy: 0.6094 - lr: 0.0100
# Epoch 72/150
# 225/225 [==============================] - 43s 191ms/step - loss: 0.7912 - accuracy: 0.7053 - val_loss: 1.1191 - val_accuracy: 0.6108 - lr: 0.0100
# Epoch 73/150
# 225/225 [==============================] - 43s 190ms/step - loss: 0.7844 - accuracy: 0.7059 - val_loss: 1.1026 - val_accuracy: 0.6121 - lr: 0.0100
# Epoch 74/150
# 225/225 [==============================] - 42s 185ms/step - loss: 0.7850 - accuracy: 0.7085 - val_loss: 1.0647 - val_accuracy: 0.6417 - lr: 0.0100
# Epoch 75/150
# 225/225 [==============================] - 43s 192ms/step - loss: 0.7741 - accuracy: 0.7106 - val_loss: 1.1162 - val_accuracy: 0.6350 - lr: 0.0100
# Epoch 76/150
# 225/225 [==============================] - 44s 196ms/step - loss: 0.7766 - accuracy: 0.7129 - val_loss: 1.1126 - val_accuracy: 0.6183 - lr: 0.0100
# Epoch 77/150
# 225/225 [==============================] - 46s 204ms/step - loss: 0.7698 - accuracy: 0.7123 - val_loss: 1.1444 - val_accuracy: 0.6169 - lr: 0.0100
# Epoch 78/150
# 225/225 [==============================] - 42s 186ms/step - loss: 0.7714 - accuracy: 0.7126 - val_loss: 1.2230 - val_accuracy: 0.6032 - lr: 0.0100
# Epoch 79/150
# 225/225 [==============================] - 43s 190ms/step - loss: 0.7715 - accuracy: 0.7138 - val_loss: 1.0566 - val_accuracy: 0.6422 - lr: 0.0100
# Epoch 80/150
# 225/225 [==============================] - 44s 194ms/step - loss: 0.7594 - accuracy: 0.7167 - val_loss: 1.1343 - val_accuracy: 0.6169 - lr: 0.0100
# Epoch 81/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.7615 - accuracy: 0.7166 - val_loss: 1.0732 - val_accuracy: 0.6369 - lr: 0.0100
# Epoch 82/150
# 225/225 [==============================] - 44s 196ms/step - loss: 0.7475 - accuracy: 0.7217 - val_loss: 1.0666 - val_accuracy: 0.6378 - lr: 0.0100
# Epoch 83/150
# 225/225 [==============================] - 43s 193ms/step - loss: 0.7531 - accuracy: 0.7201 - val_loss: 1.1097 - val_accuracy: 0.6411 - lr: 0.0100
# Epoch 84/150
# 225/225 [==============================] - 44s 196ms/step - loss: 0.7432 - accuracy: 0.7235 - val_loss: 1.1213 - val_accuracy: 0.6252 - lr: 0.0100
# Epoch 85/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.7480 - accuracy: 0.7235 - val_loss: 1.1479 - val_accuracy: 0.6160 - lr: 0.0100
# Epoch 86/150
# 225/225 [==============================] - 44s 196ms/step - loss: 0.7397 - accuracy: 0.7246 - val_loss: 1.1805 - val_accuracy: 0.6010 - lr: 0.0100
# Epoch 87/150
# 225/225 [==============================] - 43s 190ms/step - loss: 0.7367 - accuracy: 0.7284 - val_loss: 1.1086 - val_accuracy: 0.6252 - lr: 0.0100
# Epoch 88/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.7275 - accuracy: 0.7292 - val_loss: 1.0433 - val_accuracy: 0.6439 - lr: 0.0100
# Epoch 89/150
# 225/225 [==============================] - 43s 191ms/step - loss: 0.7316 - accuracy: 0.7312 - val_loss: 1.2181 - val_accuracy: 0.6010 - lr: 0.0100
# Epoch 90/150
# 225/225 [==============================] - 43s 190ms/step - loss: 0.7244 - accuracy: 0.7309 - val_loss: 1.1233 - val_accuracy: 0.6241 - lr: 0.0100
# Epoch 91/150
# 225/225 [==============================] - 44s 194ms/step - loss: 0.7248 - accuracy: 0.7305 - val_loss: 1.2115 - val_accuracy: 0.6141 - lr: 0.0100
# Epoch 92/150
# 225/225 [==============================] - 43s 190ms/step - loss: 0.7218 - accuracy: 0.7327 - val_loss: 1.1743 - val_accuracy: 0.6024 - lr: 0.0100
# Epoch 93/150
# 225/225 [==============================] - 44s 194ms/step - loss: 0.7142 - accuracy: 0.7327 - val_loss: 1.1174 - val_accuracy: 0.6484 - lr: 0.0100
# Epoch 94/150
# 225/225 [==============================] - 42s 188ms/step - loss: 0.7103 - accuracy: 0.7361 - val_loss: 1.0884 - val_accuracy: 0.6314 - lr: 0.0100
# Epoch 95/150
# 225/225 [==============================] - 43s 192ms/step - loss: 0.7083 - accuracy: 0.7397 - val_loss: 1.1173 - val_accuracy: 0.6250 - lr: 0.0100
# Epoch 96/150
# 225/225 [==============================] - 43s 191ms/step - loss: 0.7051 - accuracy: 0.7381 - val_loss: 1.1403 - val_accuracy: 0.6308 - lr: 0.0100
# Epoch 97/150
# 225/225 [==============================] - 41s 183ms/step - loss: 0.6985 - accuracy: 0.7419 - val_loss: 1.1244 - val_accuracy: 0.6191 - lr: 0.0100
# Epoch 98/150
# 225/225 [==============================] - 42s 185ms/step - loss: 0.7076 - accuracy: 0.7378 - val_loss: 1.1105 - val_accuracy: 0.6406 - lr: 0.0100
# Epoch 99/150
# 225/225 [==============================] - 42s 185ms/step - loss: 0.6961 - accuracy: 0.7404 - val_loss: 1.1148 - val_accuracy: 0.6389 - lr: 0.0100
# Epoch 100/150
# 225/225 [==============================] - 41s 184ms/step - loss: 0.7034 - accuracy: 0.7417 - val_loss: 1.2066 - val_accuracy: 0.6071 - lr: 0.0100
# Epoch 101/150
# 225/225 [==============================] - 42s 188ms/step - loss: 0.6921 - accuracy: 0.7422 - val_loss: 1.1059 - val_accuracy: 0.6358 - lr: 0.0100
# Epoch 102/150
# 225/225 [==============================] - 43s 192ms/step - loss: 0.6883 - accuracy: 0.7439 - val_loss: 1.1441 - val_accuracy: 0.6225 - lr: 0.0100
# Epoch 103/150
# 225/225 [==============================] - 44s 197ms/step - loss: 0.6927 - accuracy: 0.7462 - val_loss: 1.1941 - val_accuracy: 0.6141 - lr: 0.0100
# Epoch 104/150
# 225/225 [==============================] - 43s 192ms/step - loss: 0.6866 - accuracy: 0.7460 - val_loss: 1.1077 - val_accuracy: 0.6445 - lr: 0.0100
# Epoch 105/150
# 225/225 [==============================] - 43s 193ms/step - loss: 0.6747 - accuracy: 0.7507 - val_loss: 1.0941 - val_accuracy: 0.6342 - lr: 0.0100
# Epoch 106/150
# 225/225 [==============================] - 44s 196ms/step - loss: 0.6689 - accuracy: 0.7528 - val_loss: 1.2304 - val_accuracy: 0.6127 - lr: 0.0100
# Epoch 107/150
# 225/225 [==============================] - 43s 192ms/step - loss: 0.6755 - accuracy: 0.7488 - val_loss: 1.2008 - val_accuracy: 0.6133 - lr: 0.0100
# Epoch 108/150
# 225/225 [==============================] - 43s 190ms/step - loss: 0.6711 - accuracy: 0.7531 - val_loss: 1.0943 - val_accuracy: 0.6395 - lr: 0.0100
# Epoch 109/150
# 225/225 [==============================] - 48s 212ms/step - loss: 0.6624 - accuracy: 0.7536 - val_loss: 1.0947 - val_accuracy: 0.6548 - lr: 0.0100
# Epoch 110/150
# 225/225 [==============================] - 50s 223ms/step - loss: 0.6598 - accuracy: 0.7575 - val_loss: 1.1472 - val_accuracy: 0.6300 - lr: 0.0100
# Epoch 111/150
# 225/225 [==============================] - 46s 203ms/step - loss: 0.6611 - accuracy: 0.7569 - val_loss: 1.1246 - val_accuracy: 0.6347 - lr: 0.0100
# Epoch 112/150
# 225/225 [==============================] - 42s 188ms/step - loss: 0.6660 - accuracy: 0.7553 - val_loss: 1.1112 - val_accuracy: 0.6333 - lr: 0.0100
# Epoch 113/150
# 225/225 [==============================] - 44s 194ms/step - loss: 0.6547 - accuracy: 0.7583 - val_loss: 1.2305 - val_accuracy: 0.6275 - lr: 0.0100
# Epoch 114/150
# 225/225 [==============================] - 43s 193ms/step - loss: 0.6538 - accuracy: 0.7608 - val_loss: 1.0786 - val_accuracy: 0.6459 - lr: 0.0100
# Epoch 115/150
# 225/225 [==============================] - 42s 186ms/step - loss: 0.6451 - accuracy: 0.7617 - val_loss: 1.1249 - val_accuracy: 0.6428 - lr: 0.0100
# Epoch 116/150
# 225/225 [==============================] - 43s 191ms/step - loss: 0.6536 - accuracy: 0.7590 - val_loss: 1.1689 - val_accuracy: 0.6236 - lr: 0.0100
# Epoch 117/150
# 225/225 [==============================] - 43s 190ms/step - loss: 0.6374 - accuracy: 0.7664 - val_loss: 1.1705 - val_accuracy: 0.6239 - lr: 0.0100
# Epoch 118/150
# 225/225 [==============================] - 42s 186ms/step - loss: 0.6424 - accuracy: 0.7615 - val_loss: 1.1129 - val_accuracy: 0.6392 - lr: 0.0100
# Epoch 119/150
# 225/225 [==============================] - 43s 191ms/step - loss: 0.6361 - accuracy: 0.7669 - val_loss: 1.1328 - val_accuracy: 0.6381 - lr: 0.0100
# Epoch 120/150
# 225/225 [==============================] - 42s 189ms/step - loss: 0.6434 - accuracy: 0.7642 - val_loss: 1.1131 - val_accuracy: 0.6470 - lr: 0.0100
# Epoch 121/150
# 225/225 [==============================] - 42s 185ms/step - loss: 0.6315 - accuracy: 0.7657 - val_loss: 1.1400 - val_accuracy: 0.6342 - lr: 0.0100
# Epoch 122/150
# 225/225 [==============================] - 42s 185ms/step - loss: 0.6224 - accuracy: 0.7688 - val_loss: 1.1599 - val_accuracy: 0.6303 - lr: 0.0100
# Epoch 123/150
# 225/225 [==============================] - 42s 188ms/step - loss: 0.6309 - accuracy: 0.7676 - val_loss: 1.1048 - val_accuracy: 0.6411 - lr: 0.0100
# Epoch 124/150
# 225/225 [==============================] - 42s 189ms/step - loss: 0.6265 - accuracy: 0.7706 - val_loss: 1.1450 - val_accuracy: 0.6375 - lr: 0.0100
# Epoch 125/150
# 225/225 [==============================] - 41s 183ms/step - loss: 0.6197 - accuracy: 0.7701 - val_loss: 1.1370 - val_accuracy: 0.6428 - lr: 0.0100
# Epoch 126/150
# 225/225 [==============================] - 43s 190ms/step - loss: 0.6181 - accuracy: 0.7711 - val_loss: 1.1274 - val_accuracy: 0.6414 - lr: 0.0100
# Epoch 127/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.6060 - accuracy: 0.7750 - val_loss: 1.2028 - val_accuracy: 0.6319 - lr: 0.0100
# Epoch 128/150
# 225/225 [==============================] - 43s 189ms/step - loss: 0.6230 - accuracy: 0.7715 - val_loss: 1.2058 - val_accuracy: 0.6213 - lr: 0.0100
# Epoch 129/150
# 225/225 [==============================] - 43s 190ms/step - loss: 0.6091 - accuracy: 0.7749 - val_loss: 1.1300 - val_accuracy: 0.6305 - lr: 0.0100
# Epoch 130/150
# 225/225 [==============================] - 43s 193ms/step - loss: 0.6120 - accuracy: 0.7761 - val_loss: 1.1519 - val_accuracy: 0.6328 - lr: 0.0100
# Epoch 131/150
# 225/225 [==============================] - 42s 187ms/step - loss: 0.5993 - accuracy: 0.7796 - val_loss: 1.2625 - val_accuracy: 0.6060 - lr: 0.0100
# Epoch 132/150
# 225/225 [==============================] - 42s 186ms/step - loss: 0.6003 - accuracy: 0.7779 - val_loss: 1.2396 - val_accuracy: 0.6222 - lr: 0.0100
# Epoch 133/150
# 225/225 [==============================] - 43s 189ms/step - loss: 0.6000 - accuracy: 0.7802 - val_loss: 1.0999 - val_accuracy: 0.6459 - lr: 0.0100
# Epoch 134/150
# 225/225 [==============================] - 43s 190ms/step - loss: 0.5979 - accuracy: 0.7795 - val_loss: 1.1654 - val_accuracy: 0.6336 - lr: 0.0100
# Epoch 135/150
# 225/225 [==============================] - 43s 189ms/step - loss: 0.5952 - accuracy: 0.7800 - val_loss: 1.1111 - val_accuracy: 0.6431 - lr: 0.0100
# Epoch 136/150
# 225/225 [==============================] - 43s 190ms/step - loss: 0.5969 - accuracy: 0.7791 - val_loss: 1.1504 - val_accuracy: 0.6453 - lr: 0.0100
# Epoch 137/150
# 225/225 [==============================] - 43s 193ms/step - loss: 0.5937 - accuracy: 0.7827 - val_loss: 1.1214 - val_accuracy: 0.6389 - lr: 0.0100
# Epoch 138/150
# 225/225 [==============================] - 43s 190ms/step - loss: 0.5878 - accuracy: 0.7849 - val_loss: 1.1937 - val_accuracy: 0.6247 - lr: 0.0100
# Epoch 139/150
# 225/225 [==============================] - 43s 191ms/step - loss: 0.5861 - accuracy: 0.7822 - val_loss: 1.1867 - val_accuracy: 0.6378 - lr: 0.0100
# Epoch 140/150
# 225/225 [==============================] - 43s 189ms/step - loss: 0.5832 - accuracy: 0.7869 - val_loss: 1.2139 - val_accuracy: 0.6336 - lr: 0.0100
# Epoch 141/150
# 225/225 [==============================] - 43s 193ms/step - loss: 0.5807 - accuracy: 0.7868 - val_loss: 1.1152 - val_accuracy: 0.6548 - lr: 0.0100
# Epoch 142/150
# 225/225 [==============================] - 42s 189ms/step - loss: 0.5793 - accuracy: 0.7848 - val_loss: 1.1806 - val_accuracy: 0.6506 - lr: 0.0100
# Epoch 143/150
# 225/225 [==============================] - 43s 193ms/step - loss: 0.5743 - accuracy: 0.7867 - val_loss: 1.2643 - val_accuracy: 0.6308 - lr: 0.0100
# Epoch 144/150
# 225/225 [==============================] - 43s 192ms/step - loss: 0.5695 - accuracy: 0.7921 - val_loss: 1.1851 - val_accuracy: 0.6459 - lr: 0.0100
# Epoch 145/150
# 225/225 [==============================] - 44s 194ms/step - loss: 0.5749 - accuracy: 0.7885 - val_loss: 1.1973 - val_accuracy: 0.6445 - lr: 0.0100
# Epoch 146/150
# 225/225 [==============================] - 44s 193ms/step - loss: 0.5724 - accuracy: 0.7898 - val_loss: 1.1310 - val_accuracy: 0.6470 - lr: 0.0100
# Epoch 147/150
# 225/225 [==============================] - 44s 196ms/step - loss: 0.5696 - accuracy: 0.7888 - val_loss: 1.1825 - val_accuracy: 0.6372 - lr: 0.0100
# Epoch 148/150
# 225/225 [==============================] - 42s 189ms/step - loss: 0.5636 - accuracy: 0.7939 - val_loss: 1.1939 - val_accuracy: 0.6523 - lr: 0.0100
# Epoch 149/150
# 225/225 [==============================] - 42s 187ms/step - loss: 0.5625 - accuracy: 0.7925 - val_loss: 1.1681 - val_accuracy: 0.6383 - lr: 0.0100
# Epoch 150/150
# 225/225 [==============================] - 44s 196ms/step - loss: 0.5647 - accuracy: 0.7907 - val_loss: 1.2305 - val_accuracy: 0.6353 - lr: 0.0100

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(14,8))
epochs_=np.arange(150)
ax[0].plot(epochs_,history.history['accuracy'],'-o',color='black',label='train_acc')
ax[0].plot(epochs_,history.history['val_accuracy'],'-o',color='red',label='val_acc')
ax[1].plot(epochs_ , history.history['loss'] , '-o' ,color='black',label='train_loss')
ax[1].plot(epochs_ ,history.history['val_loss'] , 'r-o' ,color='red',label='val_loss')
plt.legend()

# %%
results_test = model.evaluate_generator(test_gen)
print('test loss, test acc:', results_test)
# Out:
# test loss, test acc: [1.162683367729187, 0.6439119577407837]
